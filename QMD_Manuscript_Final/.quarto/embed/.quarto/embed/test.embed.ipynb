# %% [markdown]
# # test

# %%
#| code-fold: true
1 + 1
# Out:
# [1] 2

# %% [raw]
# <!-- -->

# %% [markdown]
# ```` markdown
# ---
# title: "test"
# format: html
# ---
#
# quarto-executable-code-5450563D
#
# ```r
# #| code-fold: true
# 1 + 1
# ```
# ````
